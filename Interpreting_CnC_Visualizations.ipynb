# %% [markdown]
# # Visualization Processes for Interpreting CnC in the NLP Domain
#
# Within this notebook is a spread of different .py files in our repository that are used to produce visualizations for our final report. Feel free to run them in any order you wish.

# %% [markdown]
# ## 6.1 Validating Our SHAP Values

# %%
# Produces scores for verification of the sum of SHAP values
# %run experiments/verify_SHAP_sum.py
# Out:
# Some weights of the model checkpoint at bert-base-uncased were not used when initializing BertForSequenceClassification: ['cls.predictions.transform.LayerNorm.bias', 'cls.predictions.transform.LayerNorm.weight', 'cls.seq_relationship.bias', 'cls.seq_relationship.weight', 'cls.predictions.bias', 'cls.predictions.transform.dense.bias', 'cls.predictions.transform.dense.weight', 'cls.predictions.decoder.weight']
# - This IS expected if you are initializing BertForSequenceClassification from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BertForSequenceClassification from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# ...

# %% [markdown]
# ## 6.2 Correct-n-Contrast Overall Observations

# %%
# Produces plot for model confidence on predictions of comments being 'toxic', for both the CnC and ERM models (on the random subsamples)
# %run experiments/plot_predictions.py
# Out:
# Some weights of the model checkpoint at bert-base-uncased were not used when initializing BertForSequenceClassification: ['cls.predictions.bias', 'cls.seq_relationship.weight', 'cls.predictions.transform.dense.bias', 'cls.predictions.transform.LayerNorm.weight', 'cls.predictions.transform.LayerNorm.bias', 'cls.seq_relationship.bias', 'cls.predictions.transform.dense.weight', 'cls.predictions.decoder.weight']
# - This IS expected if you are initializing BertForSequenceClassification from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BertForSequenceClassification from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# ...

# %% [markdown]
# ## 6.3 Single Demographic Results

# %%
# Produces demography specific plots for different demographics, including basic tables and violin plots (both raw and normalized)
# %run experiments/plot_demographic_violin.py
# Out:
#      SHAP_not_toxic  SHAP Value       id        token  abs_SHAP_toxic  \
# 0         -0.008593    0.008593  6028377      skinned        0.008593
# 1          0.001946   -0.001946  5996362        woman        0.001946
# 2         -0.000371    0.000371  5996362        woman        0.000371
# 3         -0.000805    0.000805  6049191        woman        0.000805
# 4         -0.001562    0.001562  5671172  transgender        0.001562
# ..              ...         ...      ...          ...             ...
# 219       -0.032158    0.032158  1022930        white        0.032158
# 220       -0.000044    0.000044  7071539       latino        0.000044
# 221       -0.000044    0.000044  7071539      muslims        0.000044
# 222       -0.000047    0.000047  5802195    religious        0.000047
# 223       -0.039601    0.039601  5666897        trans        0.039601
#
#      Normalized SHAP Value Model Demographic
# 0             9.751687e-05   ERM        race
# ...

# %% [markdown]
# ## 6.4 Individual Sample Analysis

# %%
# Produces analytical plots of individual samples, comparing raw SHAPs for ERM and CnC of samples with spurious tokens 
# %run experiments/plot_SHAP_comparison_by_sample.py

# %% [markdown]
# ## 6.5 Comparing Differences in SHAP Values

# %%
# Produces a plot showing the difference in SHAP values per top token
# %run experiments/plot_difference_in_SHAP_Vals_by_sample.py
