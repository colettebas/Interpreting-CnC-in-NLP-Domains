# %% [markdown]
# # Visualization Processes for Interpreting CnC in the NLP Domain
#
# Within this notebook is a spread of different .py files in our repository that are used to produce visualizations for our final report. Feel free to run them in any order you wish.

# %%
# Produces demography specific plots for different demographics, including basic tables and violin plots (both raw and normalized)
# %run plot_demographic_violin.py
# Out:
#      SHAP_not_toxic  SHAP Value       id        token  abs_SHAP_toxic  \
# 0         -0.008593    0.008593  6028377      skinned        0.008593
# 1          0.001946   -0.001946  5996362        woman        0.001946
# 2         -0.000371    0.000371  5996362        woman        0.000371
# 3         -0.000805    0.000805  6049191        woman        0.000805
# 4         -0.001562    0.001562  5671172  transgender        0.001562
# ..              ...         ...      ...          ...             ...
# 219       -0.032158    0.032158  1022930        white        0.032158
# 220       -0.000044    0.000044  7071539       latino        0.000044
# 221       -0.000044    0.000044  7071539      muslims        0.000044
# 222       -0.000047    0.000047  5802195    religious        0.000047
# 223       -0.039601    0.039601  5666897        trans        0.039601
#
#      Normalized SHAP Value Model Demographic
# 0             9.751687e-05   ERM        race
# 1            -2.208523e-05   ERM   sexuality
# 2             4.210322e-06   ERM   sexuality
# 3             9.134553e-06   ERM   sexuality
# 4             1.772403e-05   ERM   sexuality
# ..                     ...   ...         ...
# 219           1.800895e-04   CnC        race
# 220           2.449261e-07   CnC        race
# 221           2.449261e-07   CnC    religion
# 222           2.648812e-07   CnC    religion
# 223           2.217698e-04   CnC   sexuality
#
# [224 rows x 8 columns]

# %%
# Produces a plot showing the difference in SHAP values per top token
# %run plot_difference_in_SHAP_Vals_by_sample.py

# %%
# Produces plot for model confidence on predictions of comments being 'toxic', for both the CnC and ERM models (on the random subsamples)
# %run plot_predictions.py
# Out:
# Some weights of the model checkpoint at bert-base-uncased were not used when initializing BertForSequenceClassification: ['cls.predictions.transform.LayerNorm.bias', 'cls.predictions.transform.dense.bias', 'cls.predictions.bias', 'cls.seq_relationship.bias', 'cls.predictions.transform.dense.weight', 'cls.seq_relationship.weight', 'cls.predictions.decoder.weight', 'cls.predictions.transform.LayerNorm.weight']
# - This IS expected if you are initializing BertForSequenceClassification from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BertForSequenceClassification from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights of BertForSequenceClassification were not initialized from the model checkpoint at bert-base-uncased and are newly initialized: ['classifier.weight', 'classifier.bias']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# log.missing_keys: []
# `return_all_scores` is now deprecated,  if want a similar funcionality use `top_k=None` instead of `return_all_scores=True` or `top_k=1` instead of `return_all_scores=False`.
# Some weights of the model checkpoint at bert-base-uncased were not used when initializing BertForSequenceClassification: ['cls.predictions.transform.LayerNorm.bias', 'cls.predictions.transform.dense.bias', 'cls.predictions.bias', 'cls.seq_relationship.bias', 'cls.predictions.transform.dense.weight', 'cls.seq_relationship.weight', 'cls.predictions.decoder.weight', 'cls.predictions.transform.LayerNorm.weight']
# - This IS expected if you are initializing BertForSequenceClassification from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BertForSequenceClassification from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights of BertForSequenceClassification were not initialized from the model checkpoint at bert-base-uncased and are newly initialized: ['classifier.weight', 'classifier.bias']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# log.missing_keys: []

# %%
# Produces analytical plots of individual samples, comparing raw SHAPs for ERM and CnC of samples with spurious tokens 
# %run plot_SHAP_comparison_by_sample.py
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# D:\Users\ortiz\Desktop\The Tree\Interpreting-CnC-in-NLP-Domains\plot_SHAP_comparison_by_sample.py in <module>
#      49     ax.set_title('SHAP Value by Model for Sample ' + str(sample_id))
#      50     ax.legend()
# ---> 51     ax.set_yticks(y_pos, labels=cnc_SHAP_values['token'])
#      52     ax.invert_yaxis()  # labels read top-to-bottom
#      53
#
# ~\anaconda3\lib\site-packages\matplotlib\axes\_base.py in wrapper(self, *args, **kwargs)
#      61
#      62         def wrapper(self, *args, **kwargs):
# ---> 63             return get_method(self)(*args, **kwargs)
#      64
#      65         wrapper.__module__ = owner.__module__
#
# ~\anaconda3\lib\site-packages\matplotlib\cbook\deprecation.py in wrapper(*args, **kwargs)
#     449                 "parameter will become keyword-only %(removal)s.",
#     450                 name=name, obj_type=f"parameter of {func.__name__}()")
# --> 451         return func(*args, **kwargs)
#     452
#     453     return wrapper
#
# TypeError: set_ticks() got an unexpected keyword argument 'labels'

# %%
# Produces scores for verification of the sum of SHAP values
# %run verify_SHAP_sum.py
# Out:
# Some weights of the model checkpoint at bert-base-uncased were not used when initializing BertForSequenceClassification: ['cls.predictions.transform.LayerNorm.bias', 'cls.predictions.transform.dense.bias', 'cls.predictions.bias', 'cls.seq_relationship.bias', 'cls.predictions.transform.dense.weight', 'cls.seq_relationship.weight', 'cls.predictions.decoder.weight', 'cls.predictions.transform.LayerNorm.weight']
# - This IS expected if you are initializing BertForSequenceClassification from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BertForSequenceClassification from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights of BertForSequenceClassification were not initialized from the model checkpoint at bert-base-uncased and are newly initialized: ['classifier.weight', 'classifier.bias']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# log.missing_keys: []
# `return_all_scores` is now deprecated,  if want a similar funcionality use `top_k=None` instead of `return_all_scores=True` or `top_k=1` instead of `return_all_scores=False`.
# Some weights of the model checkpoint at bert-base-uncased were not used when initializing BertForSequenceClassification: ['cls.predictions.transform.LayerNorm.bias', 'cls.predictions.transform.dense.bias', 'cls.predictions.bias', 'cls.seq_relationship.bias', 'cls.predictions.transform.dense.weight', 'cls.seq_relationship.weight', 'cls.predictions.decoder.weight', 'cls.predictions.transform.LayerNorm.weight']
# - This IS expected if you are initializing BertForSequenceClassification from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BertForSequenceClassification from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights of BertForSequenceClassification were not initialized from the model checkpoint at bert-base-uncased and are newly initialized: ['classifier.weight', 'classifier.bias']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# log.missing_keys: []
# --------- ERM MODEL SCORES ----------
#   0%|          | 0/498 [00:00<?, ?it/s]
# Partition explainer: 2it [00:37, 37.14s/it]
# ---- SAMPLE ID 6102821-----
# ---- SAMPLE SHAP SUM -----
# -0.08048749000000001
# ---- SAMPLE TOXIC PREDICTION SCORE -----
# 0.13949520885944366
# ---- DIFFERENCE: SAMPLE PREDICTION MINUS SAMPLE SHAP SUM (EXPECTED TO BE THE SAME FOR SAMPLES WITH SAME # TOKENS) -----
# 0.21998269885944366
# ---- BASE PREDICTION (EXPECTED TO BE THE SAME AS DIFFERENCE) -----
# 0.21998271346092224
#   0%|          | 0/498 [00:00<?, ?it/s]
# Partition explainer: 2it [00:32, 32.76s/it]
# ---- SAMPLE ID 7026882-----
# ---- SAMPLE SHAP SUM -----
# -0.09331938999999997
# ---- SAMPLE TOXIC PREDICTION SCORE -----
# 0.12666331231594086
# ---- DIFFERENCE: SAMPLE PREDICTION MINUS SAMPLE SHAP SUM (EXPECTED TO BE THE SAME FOR SAMPLES WITH SAME # TOKENS) -----
# 0.21998270231594083
# ---- BASE PREDICTION (EXPECTED TO BE THE SAME AS DIFFERENCE) -----
# 0.21998271346092224
#
# --------- CNC MODEL SCORES ----------
#   0%|          | 0/498 [00:00<?, ?it/s]
# Partition explainer: 2it [00:33, 33.18s/it]
# ---- SAMPLE ID 6102821-----
# ---- SAMPLE SHAP SUM -----
# 0.1397564500000001
# ---- SAMPLE TOXIC PREDICTION SCORE -----
# 0.14493848383426666
# ---- DIFFERENCE: SAMPLE PREDICTION MINUS SAMPLE SHAP SUM (EXPECTED TO BE THE SAME FOR SAMPLES WITH SAME # TOKENS) -----
# 0.005182033834266575
# ---- BASE PREDICTION (EXPECTED TO BE THE SAME AS DIFFERENCE) -----
# 0.005182013381272554
#   0%|          | 0/498 [00:00<?, ?it/s]
# Partition explainer: 2it [00:34, 34.85s/it]
# ---- SAMPLE ID 7026882-----
# ---- SAMPLE SHAP SUM -----
# -0.0005301061582999936
# ---- SAMPLE TOXIC PREDICTION SCORE -----
# 0.004651907365769148
# ---- DIFFERENCE: SAMPLE PREDICTION MINUS SAMPLE SHAP SUM (EXPECTED TO BE THE SAME FOR SAMPLES WITH SAME # TOKENS) -----
# 0.0051820135240691415
# ---- BASE PREDICTION (EXPECTED TO BE THE SAME AS DIFFERENCE) -----
# 0.005182013381272554
