# %% [markdown]
# # Visualization Processes for Interpreting CnC in the NLP Domain
#
# Within this notebook is a spread of different .py files in our repository that are used to produce visualizations for our final report. Feel free to run them in any order you wish.

# %% [markdown]
# ## 6.1 Validating Our SHAP Values

# %%
# Produces scores for verification of the sum of SHAP values
# %run verify_SHAP_sum.py
# Out:
# Some weights of the model checkpoint at bert-base-uncased were not used when initializing BertForSequenceClassification: ['cls.seq_relationship.bias', 'cls.predictions.bias', 'cls.predictions.transform.LayerNorm.weight', 'cls.seq_relationship.weight', 'cls.predictions.decoder.weight', 'cls.predictions.transform.dense.weight', 'cls.predictions.transform.dense.bias', 'cls.predictions.transform.LayerNorm.bias']
# - This IS expected if you are initializing BertForSequenceClassification from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BertForSequenceClassification from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights of BertForSequenceClassification were not initialized from the model checkpoint at bert-base-uncased and are newly initialized: ['classifier.bias', 'classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# log.missing_keys: []
# `return_all_scores` is now deprecated,  if want a similar funcionality use `top_k=None` instead of `return_all_scores=True` or `top_k=1` instead of `return_all_scores=False`.
# Some weights of the model checkpoint at bert-base-uncased were not used when initializing BertForSequenceClassification: ['cls.seq_relationship.bias', 'cls.predictions.bias', 'cls.predictions.transform.LayerNorm.weight', 'cls.seq_relationship.weight', 'cls.predictions.decoder.weight', 'cls.predictions.transform.dense.weight', 'cls.predictions.transform.dense.bias', 'cls.predictions.transform.LayerNorm.bias']
# - This IS expected if you are initializing BertForSequenceClassification from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BertForSequenceClassification from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights of BertForSequenceClassification were not initialized from the model checkpoint at bert-base-uncased and are newly initialized: ['classifier.bias', 'classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# log.missing_keys: []
# --------- ERM MODEL SCORES ----------
# [False False False False False False False False False False False False
#  False False False False False False False False False False False False
#  False]
# [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK]
# [ True  True  True  True  True  True  True  True  True  True  True  True
#   True  True  True  True  True  True  True  True  True  True  True  True
#   True]
# Islam is a common denominator for Terrorism. We will not be silenced. Free speech in not hate speech.
# [ True  True  True  True  True  True  True  True  True  True  True False
#  False False False False False False False False False False False False
#  False]
# Islam is a common denominator for Terrorism. [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK]
# [False False False False False False False False False False False  True
#   True  True  True  True  True  True  True  True  True  True  True  True
#   True]
# [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK]We will not be silenced. Free speech in not hate speech.
# [False False False False False False False False False False False  True
#   True  True  True  True  True False False False False False False False
#  False]
# [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK]We will not be silenced. [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK]
# [False False False False False False False False False False False False
#  False False False False False  True  True  True  True  True  True  True
#   True]
# [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK]Free speech in not hate speech.
# [ True  True  True  True  True False False False False False False False
#  False False False False False False False False False False False False
#  False]
# Islam is a common [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK]
# [False False False False False  True  True  True  True  True  True False
#  False False False False False False False False False False False False
#  False]
# [MASK] [MASK] [MASK] [MASK]denominator for Terrorism. [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK]
# [ True  True  True  True  True  True  True  True  True  True  True  True
#   True  True  True  True  True False False False False False False False
#  False]
# Islam is a common denominator for Terrorism. We will not be silenced. [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK]
# [ True  True  True  True  True  True  True  True  True  True  True False
#  False False False False False  True  True  True  True  True  True  True
#   True]
# Islam is a common denominator for Terrorism. [MASK] [MASK] [MASK] [MASK] [MASK] [MASK]Free speech in not hate speech.
# [ True  True False False False False False False False False False False
#  False False False False False False False False False False False False
#  False]
# Islam [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK]
# [False False  True  True  True False False False False False False False
#  False False False False False False False False False False False False
#  False]
# [MASK]is a common [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK]
# [False False False False False False False False False False False  True
#   True  True  True  True False False False False False False False False
#  False]
# [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK]We will not be silenced [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK]
# [False False False False False False False False False False False False
#  False False False False  True False False False False False False False
#  False]
# [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK]. [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK]
# [ True  True False False False  True  True  True  True  True  True False
#  False False False False False False False False False False False False
#  False]
# Islam [MASK] [MASK] [MASK]denominator for Terrorism. [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK]
# [False False  True  True  True  True  True  True  True  True  True False
#  False False False False False False False False False False False False
#  False]
# [MASK]is a common denominator for Terrorism. [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK]
# [ True  True  True  True  True  True  True  True False False False False
#  False False False False False False False False False False False False
#  False]
# Islam is a common denominator [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK]
# [ True  True  True  True  True False False False  True  True  True False
#  False False False False False False False False False False False False
#  False]
# Islam is a common [MASK] [MASK] [MASK]for Terrorism. [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK]
# [False False False False False False False False False False False  True
#   True False False False False False False False False False False False
#  False]
# [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK]We will [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK]
# [False False False False False False False False False False False False
#  False  True  True  True False False False False False False False False
#  False]
# [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK]not be silenced [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK]
# [False False False False False False False False False False False  True
#   True  True  True  True  True  True  True  True  True  True  True  True
#  False]
# [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK]We will not be silenced. Free speech in not hate speech.
# [False False False False False False False False False False False  True
#   True  True  True  True  True False False False False False False False
#   True]
# [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK]We will not be silenced. [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK]
# [ True  True  True  True  True False False False  True  True False False
#  False False False False False False False False False False False False
#  False]
# Islam is a common [MASK] [MASK] [MASK]for Terrorism [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK]
# [ True  True  True  True  True False False False False False  True False
#  False False False False False False False False False False False False
#  False]
# Islam is a common [MASK] [MASK] [MASK] [MASK] [MASK]. [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK]
# [ True  True  True  True  True  True  True  True  True  True False False
#  False False False False False False False False False False False False
#  False]
# Islam is a common denominator for Terrorism [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK]
# [ True  True  True  True  True  True  True  True False False  True False
#  False False False False False False False False False False False False
#  False]
# Islam is a common denominator [MASK] [MASK]. [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK]
# [False False False False False False False False False False False  True
#   True False False False  True False False False False False False False
#  False]
# [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK]We will [MASK] [MASK] [MASK]. [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK]
# [False False False False False False False False False False False False
#  False  True  True  True  True False False False False False False False
#  False]
# [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK]not be silenced. [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK]
# [ True False False False False False False False False False False False
#  False False False False False False False False False False False False
#  False]
# [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK]
# [False  True False False False False False False False False False False
#  False False False False False False False False False False False False
#  False]
# Islam [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK]
# [ True  True  True  True  True  True  True  True  True  True  True  True
#   True  True  True  True False  True  True  True  True  True  True  True
#   True]
# Islam is a common denominator for Terrorism. We will not be silenced [MASK]Free speech in not hate speech.
# [ True  True  True  True  True  True  True  True  True  True  True False
#  False False False False  True  True  True  True  True  True  True  True
#   True]
# Islam is a common denominator for Terrorism. [MASK] [MASK] [MASK] [MASK] [MASK]. Free speech in not hate speech.
# [False False False False False False False False False False False  True
#   True  True  True  True False  True  True  True  True  True  True  True
#   True]
# [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK]We will not be silenced [MASK]Free speech in not hate speech.
# [False False False False False False False False False False False False
#  False False False False  True  True  True  True  True  True  True  True
#   True]
# [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK]. Free speech in not hate speech.
# [ True False  True  True  True False False False False False False False
#  False False False False False False False False False False False False
#  False]
# [MASK]is a common [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK]
# [False  True  True  True  True False False False False False False False
#  False False False False False False False False False False False False
#  False]
# Islam is a common [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK]
# [False False False False False False False False False False False  True
#  False False False False False False False False False False False False
#  False]
# [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK]We [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK]
# [False False False False False False False False False False False False
#   True False False False False False False False False False False False
#  False]
# [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK]will [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK]
# [False False False False False  True  True  True False False False False
#  False False False False False False False False False False False False
#  False]
# [MASK] [MASK] [MASK] [MASK]denominator [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK]
# [False False False False False False False False  True  True  True False
#  False False False False False False False False False False False False
#  False]
# [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK]for Terrorism. [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK]
# [False False False False False  True  True False  True  True  True False
#  False False False False False False False False False False False False
#  False]
# [MASK] [MASK] [MASK] [MASK]denomi [MASK]for Terrorism. [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK]
# [False False False False False False False  True  True  True  True False
#  False False False False False False False False False False False False
#  False]
# [MASK] [MASK] [MASK] [MASK] [MASK] [MASK]nator for Terrorism. [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK]
# [False False False False False  True  True  True  True  True False False
#  False False False False False False False False False False False False
#  False]
# [MASK] [MASK] [MASK] [MASK]denominator for Terrorism [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK]
# [False False False False False  True  True  True False False  True False
#  False False False False False False False False False False False False
#  False]
# [MASK] [MASK] [MASK] [MASK]denominator [MASK] [MASK]. [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK]
# [False False False False False False False False False False False False
#  False False False False False  True  True  True  True  True  True  True
#  False]
# [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK]Free speech in not hate speech.
# [False False False False False False False False False False False False
#  False False False False False False False False False False False False
#   True]
# [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK]
#   0%|          | 0/498 [00:00<?, ?it/s]
# [False False False False False  True  True  True  True False  True False
#  False False False False False False False False False False False False
#  False]
# [MASK] [MASK] [MASK] [MASK]denominator for [MASK]. [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK]
# [False False False False False  True  True  True False  True  True False
#  False False False False False False False False False False False False
#  False]
# [MASK] [MASK] [MASK] [MASK]denominator [MASK]Terrorism. [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK]
# [ True  True  True  True  True  True  True  True  True  True  True  True
#   True  True  True  True  True  True  True  True  True  True  True  True
#  False]
# Islam is a common denominator for Terrorism. We will not be silenced. Free speech in not hate speech.
# [ True  True  True  True  True  True  True  True  True  True  True  True
#   True  True  True  True  True False False False False False False False
#   True]
# Islam is a common denominator for Terrorism. We will not be silenced. [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK]
# [False False False False False False False False False False False  True
#   True False False False False  True  True  True  True  True  True  True
#   True]
# [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK]We will [MASK] [MASK] [MASK] [MASK]Free speech in not hate speech.
# [False False False False False False False False False False False False
#  False  True  True  True False  True  True  True  True  True  True  True
#   True]
# [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK]not be silenced [MASK]Free speech in not hate speech.
# [ True  True  True  True  True  True  True False  True  True  True False
#  False False False False False False False False False False False False
#  False]
# Islam is a common denomi [MASK]for Terrorism. [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK]
# [ True  True  True  True  True False False  True  True  True  True False
#  False False False False False False False False False False False False
#  False]
# Islam is a common [MASK] [MASK]nator for Terrorism. [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK]
# [False False False False False False False False  True  True False False
#  False False False False False False False False False False False False
#  False]
# [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK]for Terrorism [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK]
# [False False False False False False False False False False  True False
#  False False False False False False False False False False False False
#  False]
# [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK]. [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK]
# [False False  True  True False False False False False False False False
#  False False False False False False False False False False False False
#  False]
# [MASK]is a [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK]
# [False False False False  True False False False False False False False
#  False False False False False False False False False False False False
#  False]
# [MASK] [MASK] [MASK]common [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK]
# [False False  True  True False  True  True  True  True  True  True False
#  False False False False False False False False False False False False
#  False]
# [MASK]is a [MASK]denominator for Terrorism. [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK]
# [False False False False  True  True  True  True  True  True  True False
#  False False False False False False False False False False False False
#  False]
# [MASK] [MASK] [MASK]common denominator for Terrorism. [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK]
# [ True False False False False  True  True  True  True  True  True False
#  False False False False False False False False False False False False
#  False]
# [MASK] [MASK] [MASK] [MASK]denominator for Terrorism. [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK]
# [False  True False False False  True  True  True  True  True  True False
#  False False False False False False False False False False False False
#  False]
# Islam [MASK] [MASK] [MASK]denominator for Terrorism. [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK]
# [False False False False False False False False False False False  True
#   True  True  True  True  True  True  True  True  True False False False
#  False]
# [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK]We will not be silenced. Free speech in not [MASK] [MASK] [MASK]
# [False False False False False False False False False False False  True
#   True  True  True  True  True False False False False  True  True  True
#  False]
# [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK]We will not be silenced. [MASK] [MASK] [MASK] [MASK]hate speech.
# [False False False False False False False False False False False  True
#   True  True  True  True  True  True  True  True  True False False False
#   True]
# [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK]We will not be silenced. Free speech in not [MASK] [MASK] [MASK]
# [False False False False False False False False False False False  True
#   True  True  True  True  True False False False False  True  True  True
#   True]
# [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK]We will not be silenced. [MASK] [MASK] [MASK] [MASK]hate speech.
# [False False False False False False False False False False False  True
#   True  True  True  True  True False False False False  True  True False
#  False]
# [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK]We will not be silenced. [MASK] [MASK] [MASK] [MASK]hate speech [MASK]
# [False False False False False False False False False False False  True
#   True  True  True  True  True False False False False False False  True
#  False]
# [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK]We will not be silenced. [MASK] [MASK] [MASK] [MASK] [MASK] [MASK].
# [False False False False False  True False  True  True  True  True False
#  False False False False False False False False False False False False
#  False]
# [MASK] [MASK] [MASK] [MASK]den [MASK]nator for Terrorism. [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK]
# [False False False False False False  True  True  True  True  True False
#  False False False False False False False False False False False False
#  False]
# [MASK] [MASK] [MASK] [MASK] [MASK]ominator for Terrorism. [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK]
# [False False False False False False False False False False False  True
#   True  True  True  True  True False False False False  True  True False
#   True]
# [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK]We will not be silenced. [MASK] [MASK] [MASK] [MASK]hate speech [MASK]
# [False False False False False False False False False False False  True
#   True  True  True  True  True False False False False False False  True
#   True]
# [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK]We will not be silenced. [MASK] [MASK] [MASK] [MASK] [MASK] [MASK].
# [ True  True  True  True  True  True  True  True  True  True  True False
#  False False False False False  True  True  True  True  True  True  True
#  False]
# Islam is a common denominator for Terrorism. [MASK] [MASK] [MASK] [MASK] [MASK] [MASK]Free speech in not hate speech.
# [ True  True  True  True  True  True  True  True  True  True  True False
#  False False False False False False False False False False False False
#   True]
# Islam is a common denominator for Terrorism. [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK]
# [ True  True  True  True  True  True  True  True  True  True  True  True
#   True False False False  True  True  True  True  True  True  True  True
#   True]
# Islam is a common denominator for Terrorism. We will [MASK] [MASK] [MASK]. Free speech in not hate speech.
# [ True  True  True  True  True  True  True  True  True  True  True False
#  False  True  True  True  True  True  True  True  True  True  True  True
#   True]
# Islam is a common denominator for Terrorism. [MASK] [MASK]not be silenced. Free speech in not hate speech.
# [ True  True  True  True False False False False False False False False
#  False False False False False False False False False False False False
#  False]
# Islam is a [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK]
# [ True  True False False  True False False False False False False False
#  False False False False False False False False False False False False
#  False]
# Islam [MASK] [MASK]common [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK]
# [False False False False False  True  True False False False False False
#  False False False False False False False False False False False False
#  False]
# [MASK] [MASK] [MASK] [MASK]denomi [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK]
# [False False False False False False False  True False False False False
#  False False False False False False False False False False False False
#  False]
# [MASK] [MASK] [MASK] [MASK] [MASK] [MASK]nator [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK]
# [False False False False False False False False False False False  True
#  False False False False False  True  True  True  True  True  True  True
#   True]
# [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK]We [MASK] [MASK] [MASK] [MASK] [MASK]Free speech in not hate speech.
# [False False False False False False False False False False False False
#   True False False False False  True  True  True  True  True  True  True
#   True]
# [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK]will [MASK] [MASK] [MASK] [MASK]Free speech in not hate speech.
# [False False False False False  True False False False False False False
#  False False False False False False False False False False False False
#  False]
# [MASK] [MASK] [MASK] [MASK]den [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK]
# [False False False False False False  True False False False False False
#  False False False False False False False False False False False False
#  False]
# [MASK] [MASK] [MASK] [MASK] [MASK]omi [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK]
# [False False False False False False False False False False False  True
#  False False False False  True False False False False False False False
#  False]
# [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK]We [MASK] [MASK] [MASK] [MASK]. [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK]
# [False False False False False False False False False False False False
#   True False False False  True False False False False False False False
#  False]
# [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK]will [MASK] [MASK] [MASK]. [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK]
# [False False False False False False False False False False False  True
#   True False False False  True  True  True  True  True  True  True  True
#   True]
# [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK]We will [MASK] [MASK] [MASK]. Free speech in not hate speech.
# [False False False False False False False False False False False False
#  False  True  True  True  True  True  True  True  True  True  True  True
#   True]
# [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK]not be silenced. Free speech in not hate speech.
# [ True  True  True  True  True False False False  True False  True False
#  False False False False False False False False False False False False
#  False]
# Islam is a common [MASK] [MASK] [MASK]for [MASK]. [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK]
# [ True  True  True  True  True False False False False  True  True False
#  False False False False False False False False False False False False
#  False]
# Islam is a common [MASK] [MASK] [MASK] [MASK]Terrorism. [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK]
# [False False False False False False False False False False False False
#  False  True  True False False False False False False False False False
#  False]
# [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK]not be [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK]
# [False False False False False False False False False False False False
#  False False False  True False False False False False False False False
#  False]
# [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK]silenced [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK]
# [ True  True  True  True False  True  True  True  True  True  True False
#  False False False False False False False False False False False False
#  False]
# Islam is a [MASK]denominator for Terrorism. [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK]
# [ True  True False False  True  True  True  True  True  True  True False
#  False False False False False False False False False False False False
#  False]
# Islam [MASK] [MASK]common denominator for Terrorism. [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK]
# [False False False False False  True False False  True  True  True False
#  False False False False False False False False False False False False
#  False]
# [MASK] [MASK] [MASK] [MASK]den [MASK] [MASK]for Terrorism. [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK]
# [False False False False False False  True False  True  True  True False
#  False False False False False False False False False False False False
#  False]
# [MASK] [MASK] [MASK] [MASK] [MASK]omi [MASK]for Terrorism. [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK]
# [ True  True  True  True  True False False False  True False False False
#  False False False False False False False False False False False False
#  False]
# Islam is a common [MASK] [MASK] [MASK]for [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK]
# [ True  True  True  True  True False False False False  True False False
#  False False False False False False False False False False False False
#  False]
# Islam is a common [MASK] [MASK] [MASK] [MASK]Terrorism [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK]
# [ True False  True  True  True  True  True  True  True  True  True False
#  False False False False False False False False False False False False
#  False]
# [MASK]is a common denominator for Terrorism. [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK]
# [False  True  True  True  True  True  True  True  True  True  True False
#  False False False False False False False False False False False False
#  False]
# Islam is a common denominator for Terrorism. [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK]
# [False False False False False False False False False False False False
#  False False False False False  True  True  True  True False False False
#  False]
# [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK]Free speech in not [MASK] [MASK] [MASK]
# [False False False False False False False False False False False False
#  False False False False False False False False False  True  True  True
#  False]
# [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK]hate speech.
# [False False False False False False False False False False False False
#  False False False False False  True  True  True  True False False False
#   True]
# [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK]Free speech in not [MASK] [MASK] [MASK]
# [False False False False False False False False False False False False
#  False False False False False False False False False  True  True  True
#   True]
# [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK]hate speech.
# [False False False False False False False False False False False  True
#  False  True  True  True False False False False False False False False
#  False]
# [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK]We [MASK]not be silenced [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK]
# [False False False False False False False False False False False False
#   True  True  True  True False False False False False False False False
#  False]
# [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK]will not be silenced [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK]
# [False False False False False False False False False False False False
#  False False False False False False False False False  True  True False
#   True]
# [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK]hate speech [MASK]
# [False False False False False False False False False False False False
#  False False False False False False False False False False False  True
#   True]
# [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK].
# [False False False False False False False False False False False False
#  False False False False False False False False False  True  True False
#  False]
# [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK]hate speech [MASK]
# [False False False False False False False False False False False False
#  False False False False False False False False False False False  True
#  False]
# [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK].
# [ True  True  True  True  True  True  True  True  True  True  True  True
#   True  True  True  True  True  True  True  True  True False False False
#  False]
# Islam is a common denominator for Terrorism. We will not be silenced. Free speech in not [MASK] [MASK] [MASK]
# [ True  True  True  True  True  True  True  True  True  True  True  True
#   True  True  True  True  True False False False False  True  True  True
#  False]
# Islam is a common denominator for Terrorism. We will not be silenced. [MASK] [MASK] [MASK] [MASK]hate speech.
# [ True  True  True  True  True  True  True  True  True  True  True  True
#   True  True  True  True  True  True  True False False  True  True  True
#  False]
# Islam is a common denominator for Terrorism. We will not be silenced. Free speech [MASK] [MASK]hate speech.
# [ True  True  True  True  True  True  True  True  True  True  True  True
#   True  True  True  True  True False False  True  True  True  True  True
#  False]
# Islam is a common denominator for Terrorism. We will not be silenced. [MASK] [MASK]in not hate speech.
# [ True  True  True  True  True  True  True  True  True  True  True  True
#   True  True  True  True  True False False False False  True  True False
#  False]
# Islam is a common denominator for Terrorism. We will not be silenced. [MASK] [MASK] [MASK] [MASK]hate speech [MASK]
# [ True  True  True  True  True  True  True  True  True  True  True  True
#   True  True  True  True  True False False False False False False  True
#  False]
# Islam is a common denominator for Terrorism. We will not be silenced. [MASK] [MASK] [MASK] [MASK] [MASK] [MASK].
# [ True  True  True  True  True  True  True  True  True  True  True  True
#   True  True  True  True  True  True  True  True  True False False False
#   True]
# Islam is a common denominator for Terrorism. We will not be silenced. Free speech in not [MASK] [MASK] [MASK]
# [ True  True  True  True  True  True  True  True  True  True  True  True
#   True  True  True  True  True False False False False  True  True  True
#   True]
# Islam is a common denominator for Terrorism. We will not be silenced. [MASK] [MASK] [MASK] [MASK]hate speech.
# [ True  True  True  True  True  True  True  True  True  True  True  True
#   True  True  True  True  True  True  True False False  True  True  True
#   True]
# Islam is a common denominator for Terrorism. We will not be silenced. Free speech [MASK] [MASK]hate speech.
# [ True  True  True  True  True  True  True  True  True  True  True  True
#   True  True  True  True  True False False  True  True  True  True  True
#   True]
# Islam is a common denominator for Terrorism. We will not be silenced. [MASK] [MASK]in not hate speech.
# [ True  True  True  True  True  True  True  True  True  True  True  True
#   True  True  True  True  True False False False False  True  True False
#   True]
# Islam is a common denominator for Terrorism. We will not be silenced. [MASK] [MASK] [MASK] [MASK]hate speech [MASK]
# [ True  True  True  True  True  True  True  True  True  True  True  True
#   True  True  True  True  True False False False False False False  True
#   True]
# Islam is a common denominator for Terrorism. We will not be silenced. [MASK] [MASK] [MASK] [MASK] [MASK] [MASK].
# [ True  True  True  True  True  True  True  True  True  True  True  True
#   True  True  True  True  True  True  True  True False  True  True  True
#  False]
# Islam is a common denominator for Terrorism. We will not be silenced. Free speech in [MASK]hate speech.
# [ True  True  True  True  True  True  True  True  True  True  True  True
#   True  True  True  True  True  True  True False  True  True  True  True
#  False]
# Islam is a common denominator for Terrorism. We will not be silenced. Free speech [MASK]not hate speech.
# [ True  True  True  True  True  True  True  True  True  True  True  True
#   True  True  True  True  True  True  True  True False  True  True  True
#   True]
# Islam is a common denominator for Terrorism. We will not be silenced. Free speech in [MASK]hate speech.
# [ True  True  True  True  True  True  True  True  True  True  True  True
#   True  True  True  True  True  True  True False  True  True  True  True
#   True]
# Islam is a common denominator for Terrorism. We will not be silenced. Free speech [MASK]not hate speech.
# [ True  True  True  True  True  True  True  True  True  True  True  True
#   True  True  True  True False False False False False False False False
#  False]
# Islam is a common denominator for Terrorism. We will not be silenced [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK]
# [ True  True  True  True  True  True  True  True  True  True  True False
#  False False False False  True False False False False False False False
#  False]
# Islam is a common denominator for Terrorism. [MASK] [MASK] [MASK] [MASK] [MASK]. [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK]
# [ True  True  True  True  True  True  True  True  True  True  True  True
#   True  True  True  True  True  True  True  True  True  True  True False
#  False]
# Islam is a common denominator for Terrorism. We will not be silenced. Free speech in not hate speech [MASK]
# [ True  True  True  True  True  True  True  True  True  True  True  True
#   True  True  True  True  True  True  True  True  True False False  True
#  False]
# Islam is a common denominator for Terrorism. We will not be silenced. Free speech in not [MASK] [MASK].
# [ True  True  True  True  True  True  True  True  True  True  True  True
#   True False False False  True False False False False False False False
#  False]
# Islam is a common denominator for Terrorism. We will [MASK] [MASK] [MASK]. [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK]
# [ True  True  True  True  True  True  True  True  True  True  True False
#  False  True  True  True  True False False False False False False False
#  False]
# Islam is a common denominator for Terrorism. [MASK] [MASK]not be silenced. [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK]
# [ True  True  True  True  True  True  True  True  True  True  True  True
#   True  True  True  True  True  True  True  True  True  True  True False
#   True]
# Islam is a common denominator for Terrorism. We will not be silenced. Free speech in not hate speech [MASK]
# [ True  True  True  True  True  True  True  True  True  True  True  True
#   True  True  True  True  True  True  True  True  True False False  True
#   True]
# Islam is a common denominator for Terrorism. We will not be silenced. Free speech in not [MASK] [MASK].
# [ True  True  True  True  True  True False False  True  True  True False
#  False False False False False False False False False False False False
#  False]
# Islam is a common den [MASK] [MASK]for Terrorism. [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK]
# [ True  True  True  True  True False  True False  True  True  True False
#  False False False False False False False False False False False False
#  False]
# Islam is a common [MASK]omi [MASK]for Terrorism. [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK]
# [False False False False False False False False False False False  True
#   True  True  True  True  True  True  True False False  True  True  True
#  False]
# [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK]We will not be silenced. Free speech [MASK] [MASK]hate speech.
# [False False False False False False False False False False False  True
#   True  True  True  True  True False False  True  True  True  True  True
#  False]
# [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK]We will not be silenced. [MASK] [MASK]in not hate speech.
# [False False False False False False False False False False False  True
#   True  True  True  True  True  True  True False False  True  True  True
#   True]
# [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK]We will not be silenced. Free speech [MASK] [MASK]hate speech.
# [False False False False False False False False False False False  True
#   True  True  True  True  True False False  True  True  True  True  True
#   True]
# [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK]We will not be silenced. [MASK] [MASK]in not hate speech.
# [ True  True  True  True  True  True  True  True  True False  True False
#  False False False False False False False False False False False False
#  False]
# Islam is a common denominator for [MASK]. [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK]
# [ True  True  True  True  True  True  True  True False  True  True False
#  False False False False False False False False False False False False
#  False]
# Islam is a common denominator [MASK]Terrorism. [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK]
# [ True  True  True  True  True  True  True  True  True  True  True  True
#   True  True  True False  True  True  True  True  True  True  True  True
#   True]
# Islam is a common denominator for Terrorism. We will not be [MASK]. Free speech in not hate speech.
# [ True  True  True  True  True  True  True  True  True  True  True  True
#   True False False  True  True  True  True  True  True  True  True  True
#   True]
# Islam is a common denominator for Terrorism. We will [MASK] [MASK]silenced. Free speech in not hate speech.
# [False False False False False False False False False False False  True
#   True  True  True  True  True False False False False  True False False
#   True]
# [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK]We will not be silenced. [MASK] [MASK] [MASK] [MASK]hate [MASK] [MASK]
# [False False False False False False False False False False False  True
#   True  True  True  True  True False False False False False  True False
#   True]
# [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK]We will not be silenced. [MASK] [MASK] [MASK] [MASK] [MASK]speech [MASK]
# [False False False False False False False False False False False  True
#   True  True  True  True  True False False False False  True False False
#  False]
# [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK]We will not be silenced. [MASK] [MASK] [MASK] [MASK]hate [MASK] [MASK]
# [False False False False False False False False False False False  True
#   True  True  True  True  True False False False False False  True False
#  False]
# [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK]We will not be silenced. [MASK] [MASK] [MASK] [MASK] [MASK]speech [MASK]
# [False False False False False False False False False False False  True
#   True  True  True  True  True False False False False  True False  True
#  False]
# [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK]We will not be silenced. [MASK] [MASK] [MASK] [MASK]hate [MASK].
# [False False False False False False False False False False False  True
#   True  True  True  True  True False False False False False  True  True
#  False]
# [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK]We will not be silenced. [MASK] [MASK] [MASK] [MASK] [MASK]speech.
# [False False False False False False False False False False False  True
#   True  True  True  True  True False False False False  True False  True
#   True]
# [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK]We will not be silenced. [MASK] [MASK] [MASK] [MASK]hate [MASK].
# [False False False False False False False False False False False  True
#   True  True  True  True  True False False False False False  True  True
#   True]
# [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK]We will not be silenced. [MASK] [MASK] [MASK] [MASK] [MASK]speech.
# [False False False False False False False False False False False False
#  False  True  True False  True False False False False False False False
#  False]
# [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK]not be [MASK]. [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK]
# [False False False False False False False False False False False False
#  False False False  True  True False False False False False False False
#  False]
# [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK]silenced. [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK]
# [ True  True  True  True  True  True  True  True  True  True  True False
#  False False False False False  True  True  True  True False False False
#   True]
# Islam is a common denominator for Terrorism. [MASK] [MASK] [MASK] [MASK] [MASK] [MASK]Free speech in not [MASK] [MASK] [MASK]
# [ True  True  True  True  True  True  True  True  True  True  True False
#  False False False False False False False False False  True  True  True
#   True]
# ...
#   True]
# [MASK]a former atheist [MASK]its frightening to see the delusion and denial of those still held by the atheist belief.
# [ True  True False False False False  True  True  True  True  True  True
#   True  True  True  True  True  True  True  True  True  True  True  True
#  False]
# As [MASK] [MASK] [MASK] [MASK]its frightening to see the delusion and denial of those still held by the atheist belief.
# [False False  True  True  True False  True  True  True  True  True  True
#   True  True  True  True  True  True  True  True  True  True  True  True
#  False]
# [MASK]a former atheist [MASK]its frightening to see the delusion and denial of those still held by the atheist belief.
# [False False False False False False False False  True  True False False
#  False False  True  True  True  True  True  True  True  True  True  True
#  False]
# [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK]to see [MASK] [MASK] [MASK] [MASK]denial of those still held by the atheist belief.
# [False False False False False False False False False False  True False
#  False False  True  True  True  True  True  True  True  True  True  True
#  False]
# [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK]the [MASK] [MASK] [MASK]denial of those still held by the atheist belief.
# [False False False False False False False False  True  True False False
#  False False  True  True  True  True  True  True  True  True  True  True
#   True]
# [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK]to see [MASK] [MASK] [MASK] [MASK]denial of those still held by the atheist belief.
# [False False False False False False False False False False  True False
#  False False  True  True  True  True  True  True  True  True  True  True
#   True]
# [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK]the [MASK] [MASK] [MASK]denial of those still held by the atheist belief.
# [False False  True  True False False False False False False False False
#  False False False False False False False False False False False False
#  False]
# [MASK]a former [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK]
# [False False False False  True False False False False False False False
#  False False False False False False False False False False False False
#  False]
# [MASK] [MASK] [MASK]atheist [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK]
# [False False  True  True False False False False False False False False
#  False False False False False False False False False False False False
#   True]
# [MASK]a former [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK]
# [False False False False  True False False False False False False False
#  False False False False False False False False False False False False
#   True]
# [MASK] [MASK] [MASK]atheist [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK]
# [ True  True  True  True False False False False False False False False
#  False False False False False False False False False False False False
#   True]
# As a former [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK]
# [ True  True False False  True False False False False False False False
#  False False False False False False False False False False False False
#   True]
# As [MASK] [MASK]atheist [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK]
# [ True  True  True  True False False False False False False False False
#  False False False False False False False False False False False False
#  False]
# As a former [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK]
# [ True  True False False  True False False False False False False False
#  False False False False False False False False False False False False
#  False]
# As [MASK] [MASK]atheist [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK]
# [ True  True  True  True  True  True  True  True False False False False
#  False False  True  True  True  True  True  True  True  True  True  True
#  False]
# As a former atheist, its frightening [MASK] [MASK] [MASK] [MASK] [MASK] [MASK]denial of those still held by the atheist belief.
# [ True  True  True  True  True  True False False  True  True  True False
#  False False  True  True  True  True  True  True  True  True  True  True
#  False]
# As a former atheist, [MASK] [MASK]to see the [MASK] [MASK] [MASK]denial of those still held by the atheist belief.
# [ True  True  True  True  True  True  True  True False False False False
#  False False  True  True  True  True  True  True  True  True  True  True
#   True]
# As a former atheist, its frightening [MASK] [MASK] [MASK] [MASK] [MASK] [MASK]denial of those still held by the atheist belief.
# [ True  True  True  True  True  True False False  True  True  True False
#  False False  True  True  True  True  True  True  True  True  True  True
#   True]
# As a former atheist, [MASK] [MASK]to see the [MASK] [MASK] [MASK]denial of those still held by the atheist belief.
# [ True  True  True  True  True  True  True False False False False False
#  False False  True  True  True  True  True  True  True  True  True  True
#  False]
# As a former atheist, its [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK]denial of those still held by the atheist belief.
# [ True  True  True  True  True  True False  True False False False False
#  False False  True  True  True  True  True  True  True  True  True  True
#  False]
# As a former atheist, [MASK]frightening [MASK] [MASK] [MASK] [MASK] [MASK] [MASK]denial of those still held by the atheist belief.
# [ True  True  True  True  True  True  True False False False False False
#  False False  True  True  True  True  True  True  True  True  True  True
#   True]
# As a former atheist, its [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK]denial of those still held by the atheist belief.
# [ True  True  True  True  True  True False  True False False False False
#  False False  True  True  True  True  True  True  True  True  True  True
#   True]
# As a former atheist, [MASK]frightening [MASK] [MASK] [MASK] [MASK] [MASK] [MASK]denial of those still held by the atheist belief.
# [ True  True  True  True  True  True  True  True  True  True False False
#  False False  True  True  True  True  True  True  True  True  True  True
#  False]
# As a former atheist, its frightening to see [MASK] [MASK] [MASK] [MASK]denial of those still held by the atheist belief.
# [ True  True  True  True  True  True  True  True False False  True False
#  False False  True  True  True  True  True  True  True  True  True  True
#  False]
# As a former atheist, its frightening [MASK] [MASK]the [MASK] [MASK] [MASK]denial of those still held by the atheist belief.
# [ True  True  True  True  True  True  True  True  True  True False False
#  False False  True  True  True  True  True  True  True  True  True  True
#   True]
# As a former atheist, its frightening to see [MASK] [MASK] [MASK] [MASK]denial of those still held by the atheist belief.
# [ True  True  True  True  True  True  True  True False False  True False
#  False False  True  True  True  True  True  True  True  True  True  True
#   True]
# As a former atheist, its frightening [MASK] [MASK]the [MASK] [MASK] [MASK]denial of those still held by the atheist belief.
# [False False False False False False  True  True  True False False False
#  False False  True  True  True  True  True  True  True  True  True  True
#   True]
# [MASK] [MASK] [MASK] [MASK] [MASK]its frightening to [MASK] [MASK] [MASK] [MASK] [MASK]denial of those still held by the atheist belief.
# [False False False False False False  True  True False  True False False
#  False False  True  True  True  True  True  True  True  True  True  True
#   True]
# [MASK] [MASK] [MASK] [MASK] [MASK]its frightening [MASK]see [MASK] [MASK] [MASK] [MASK]denial of those still held by the atheist belief.
# [False False False False False False  True  True  True False False False
#  False False  True  True  True  True  True  True  True  True  True  True
#  False]
# [MASK] [MASK] [MASK] [MASK] [MASK]its frightening to [MASK] [MASK] [MASK] [MASK] [MASK]denial of those still held by the atheist belief.
# [False False False False False False  True  True False  True False False
#  False False  True  True  True  True  True  True  True  True  True  True
#  False]
# [MASK] [MASK] [MASK] [MASK] [MASK]its frightening [MASK]see [MASK] [MASK] [MASK] [MASK]denial of those still held by the atheist belief.
# [ True  True  True  True  True  True  True  True  True  True  True  True
#   True  True  True  True False False  True  True  True  True  True  True
#  False]
# As a former atheist, its frightening to see the delusion and denial of [MASK] [MASK]held by the atheist belief.
# [ True  True  True  True  True  True  True  True  True  True  True  True
#   True  True False False  True  True  True  True  True  True  True  True
#  False]
# As a former atheist, its frightening to see the delusion and [MASK] [MASK]those still held by the atheist belief.
# [ True  True  True  True  True  True  True  True  True  True  True  True
#   True  True  True  True False False  True  True  True  True  True  True
#   True]
# As a former atheist, its frightening to see the delusion and denial of [MASK] [MASK]held by the atheist belief.
# [ True  True  True  True  True  True  True  True  True  True  True  True
#   True  True False False  True  True  True  True  True  True  True  True
#   True]
# As a former atheist, its frightening to see the delusion and [MASK] [MASK]those still held by the atheist belief.
# [False False False False False False  True False False False False False
#  False False  True  True  True  True  True  True  True  True  True  True
#   True]
# [MASK] [MASK] [MASK] [MASK] [MASK]its [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK]denial of those still held by the atheist belief.
# [False False False False False False False  True False False False False
#  False False  True  True  True  True  True  True  True  True  True  True
#   True]
# [MASK] [MASK] [MASK] [MASK] [MASK] [MASK]frightening [MASK] [MASK] [MASK] [MASK] [MASK] [MASK]denial of those still held by the atheist belief.
# [False False False False False False  True False False False False False
#  False False  True  True  True  True  True  True  True  True  True  True
#  False]
# [MASK] [MASK] [MASK] [MASK] [MASK]its [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK]denial of those still held by the atheist belief.
# [False False False False False False False  True False False False False
#  False False  True  True  True  True  True  True  True  True  True  True
#  False]
# [MASK] [MASK] [MASK] [MASK] [MASK] [MASK]frightening [MASK] [MASK] [MASK] [MASK] [MASK] [MASK]denial of those still held by the atheist belief.
# [False False False False False False False False False False False False
#  False False False False  True False False False False False False False
#   True]
# [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK]those [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK]
# [False False False False False False False False False False False False
#  False False False False False  True False False False False False False
#   True]
# [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK]still [MASK] [MASK] [MASK] [MASK] [MASK] [MASK]
# [False False False False False False False False False False False False
#  False False False False  True False False False False False False False
#  False]
# [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK]those [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK]
# [False False False False False False False False False False False False
#  False False False False False  True False False False False False False
#  False]
# [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK] [MASK]still [MASK] [MASK] [MASK] [MASK] [MASK] [MASK]
# [ True False False False False False  True  True  True  True  True  True
#   True  True  True  True  True  True  True  True  True  True  True  True
#  False]
# [MASK] [MASK] [MASK] [MASK] [MASK]its frightening to see the delusion and denial of those still held by the atheist belief.
# [False  True False False False False  True  True  True  True  True  True
#   True  True  True  True  True  True  True  True  True  True  True  True
#  False]
# As [MASK] [MASK] [MASK] [MASK]its frightening to see the delusion and denial of those still held by the atheist belief.
# [ True False False False False False  True  True  True  True  True  True
#   True  True  True  True  True  True  True  True  True  True  True  True
#   True]
# [MASK] [MASK] [MASK] [MASK] [MASK]its frightening to see the delusion and denial of those still held by the atheist belief.
# [False  True False False False False  True  True  True  True  True  True
#   True  True  True  True  True  True  True  True  True  True  True  True
#   True]
# As [MASK] [MASK] [MASK] [MASK]its frightening to see the delusion and denial of those still held by the atheist belief.
# [ True  True  True  True  True  True  True  True False False False  True
#   True  True  True  True  True  True  True  True  True  True  True  True
#  False]
# As a former atheist, its frightening [MASK] [MASK] [MASK]delusion and denial of those still held by the atheist belief.
# [ True  True  True  True  True  True False False  True  True  True  True
#   True  True  True  True  True  True  True  True  True  True  True  True
#  False]
# As a former atheist, [MASK] [MASK]to see the delusion and denial of those still held by the atheist belief.
# [ True  True  True  True  True  True  True False False False False  True
#   True  True  True  True  True  True  True  True  True  True  True  True
#  False]
# As a former atheist, its [MASK] [MASK] [MASK] [MASK]delusion and denial of those still held by the atheist belief.
# [ True  True  True  True  True  True False  True False False False  True
#   True  True  True  True  True  True  True  True  True  True  True  True
#  False]
# As a former atheist, [MASK]frightening [MASK] [MASK] [MASK]delusion and denial of those still held by the atheist belief.
# [ True  True  True  True  True  True  True  True  True  True False  True
#   True  True  True  True  True  True  True  True  True  True  True  True
#  False]
# As a former atheist, its frightening to see [MASK]delusion and denial of those still held by the atheist belief.
# [ True  True  True  True  True  True  True  True False False  True  True
#   True  True  True  True  True  True  True  True  True  True  True  True
#  False]
# As a former atheist, its frightening [MASK] [MASK]the delusion and denial of those still held by the atheist belief.
# [ True  True  True  True  True  True  True  True False False False  True
#   True  True  True  True  True  True  True  True  True  True  True  True
#   True]
# As a former atheist, its frightening [MASK] [MASK] [MASK]delusion and denial of those still held by the atheist belief.
# [ True  True  True  True  True  True False False  True  True  True  True
#   True  True  True  True  True  True  True  True  True  True  True  True
#   True]
# As a former atheist, [MASK] [MASK]to see the delusion and denial of those still held by the atheist belief.
# Partition explainer: 2it [00:51, 51.44s/it]
# ---- SAMPLE ID 7026882-----
# ---- SAMPLE SHAP SUM -----
# -0.0005301061582999936
# ---- SAMPLE TOXIC PREDICTION SCORE -----
# 0.004651907365769148
# ---- DIFFERENCE: SAMPLE PREDICTION MINUS SAMPLE SHAP SUM (EXPECTED TO BE THE SAME FOR SAMPLES WITH SAME # TOKENS) -----
# 0.0051820135240691415
# ---- BASE PREDICTION (EXPECTED TO BE THE SAME AS DIFFERENCE) -----
# 0.0051820105873048306

# %% [markdown]
# ## 6.2 Correct-n-Contrast Overall Observations

# %%
# Produces plot for model confidence on predictions of comments being 'toxic', for both the CnC and ERM models (on the random subsamples)
# %run plot_predictions.py
# Out:
# 2022-12-19 18:04:31.170200: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# Some weights of the model checkpoint at bert-base-uncased were not used when initializing BertForSequenceClassification: ['cls.seq_relationship.bias', 'cls.predictions.bias', 'cls.predictions.transform.LayerNorm.weight', 'cls.seq_relationship.weight', 'cls.predictions.decoder.weight', 'cls.predictions.transform.dense.weight', 'cls.predictions.transform.dense.bias', 'cls.predictions.transform.LayerNorm.bias']
# - This IS expected if you are initializing BertForSequenceClassification from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BertForSequenceClassification from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights of BertForSequenceClassification were not initialized from the model checkpoint at bert-base-uncased and are newly initialized: ['classifier.bias', 'classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# log.missing_keys: []
# /Users/colettebasiliere/opt/anaconda3/lib/python3.9/site-packages/transformers/pipelines/text_classification.py:89: UserWarning: `return_all_scores` is now deprecated,  if want a similar funcionality use `top_k=None` instead of `return_all_scores=True` or `top_k=1` instead of `return_all_scores=False`.
#   warnings.warn(
# Some weights of the model checkpoint at bert-base-uncased were not used when initializing BertForSequenceClassification: ['cls.seq_relationship.bias', 'cls.predictions.bias', 'cls.predictions.transform.LayerNorm.weight', 'cls.seq_relationship.weight', 'cls.predictions.decoder.weight', 'cls.predictions.transform.dense.weight', 'cls.predictions.transform.dense.bias', 'cls.predictions.transform.LayerNorm.bias']
# - This IS expected if you are initializing BertForSequenceClassification from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BertForSequenceClassification from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights of BertForSequenceClassification were not initialized from the model checkpoint at bert-base-uncased and are newly initialized: ['classifier.bias', 'classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# log.missing_keys: []

# %% [markdown]
# ## 6.3 Single Demographic Results

# %%
# Produces demography specific plots for different demographics, including basic tables and violin plots (both raw and normalized)
# %run plot_demographic_violin.py

# %% [markdown]
# ## 6.4 Individual Sample Analysis

# %%
# Produces analytical plots of individual samples, comparing raw SHAPs for ERM and CnC of samples with spurious tokens 
# %run plot_SHAP_comparison_by_sample.py
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~/Desktop/Interpreting-CnC-in-NLP-Domains/plot_SHAP_comparison_by_sample.py in <module>
#      68     ax.set_title('Normalized SHAP Value by Model for Sample ' + str(sample_id))
#      69     ax.legend()
# ---> 70     ax.set_yticks(y_pos, labels=cnc_SHAP_values['token'])
#      71     ax.invert_yaxis()  # labels read top-to-bottom
#      72
#
# ~/opt/anaconda3/lib/python3.9/site-packages/matplotlib/axes/_base.py in wrapper(self, *args, **kwargs)
#      71
#      72         def wrapper(self, *args, **kwargs):
# ---> 73             return get_method(self)(*args, **kwargs)
#      74
#      75         wrapper.__module__ = owner.__module__
#
# TypeError: set_ticks() got an unexpected keyword argument 'labels'

# %% [markdown]
# ## 6.5 Comparing Differences in SHAP Values

# %%
# Produces a plot showing the difference in SHAP values per top token
# %run plot_difference_in_SHAP_Vals_by_sample.py
